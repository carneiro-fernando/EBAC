# %% [markdown]
# <a href="https://colab.research.google.com/github/carneiro-fernando/EBAC/blob/main/Exercicios/Modulo_38.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Computação em Nuvem II
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>AWS Lambda;</li>
#   <li>AWS Step Functions;</li>
#   <li>AWS EventBridge.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. AWS Lambda

# %% [markdown]
# Replique as atividades do item 1.3 em sua conta.

# %% [markdown]
# * Criação: **Bronze function**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Teste:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Criação: **Silver function**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Teste:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Criação: **Table Function**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Teste:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2\. AWS Step Functions

# %% [markdown]
# Replique as atividades do item 2.3 em sua conta.

# %% [markdown]
# * Criação:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Teste:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 3\. AWS EventBridge

# %% [markdown]
# Replique as atividades do item 3.3 em sua conta.

# %% [markdown]
# * Criação:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Verificação:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

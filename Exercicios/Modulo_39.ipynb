# %% [markdown]
# <a href="https://colab.research.google.com/github/carneiro-fernando/EBAC/blob/main/Exercicios/Modulo_39.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Computação em Nuvem III
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>AWS EC2;</li>
#   <li>AWS SageMaker;</li>
#   <li>AWS Acesso Externo.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. AWS SageMaker

# %% [markdown]
# Replique as atividades do item 2.3 em sua conta.

# %% [markdown]
# ####**Criação de bucket e upload**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### **Criação de instancia de notebook**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### **Executando script Jupyter Lab**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2\. AWS Acesso Externo

# %% [markdown]
# Replique as atividades do item 3.1 em sua conta.

# %% [markdown]
# #### **Criação do usuário programático**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### **Criando script com acesso a AWS**

# %%
#Instalação de pacote
# !pip install boto3

#Importação de pacotes
import boto3
import pandas as pd
from getpass import getpass

# %%
#Instanciação de variáveis de acesso
print("Digite o ID")
aws_access_key_id = getpass()
print("Digite a chave")
aws_secret_access_key = getpass()

#Localização do bucket
BUCKET = 'ebac-modulo-39-sagemaker1'

#Criação de client
client = boto3.client('s3', aws_access_key_id=aws_access_key_id, aws_secret_access_key=aws_secret_access_key)

#Download do arquivo
client.download_file(BUCKET, 'cotacao.csv', 'cotacao_aws.csv')

#Leitura do arquivo
df = pd.read_csv('cotacao_aws.csv')
df.head()
# Out:
# Digite o ID
# ··········
# Digite a chave
# ··········
#          date     usd     eur     gbp
# 0  2021-01-21  5.4582  6.1896  7.3980
# 1  2021-01-20  5.4191  6.1290  7.3673
# 2  2021-01-19  5.4383  6.1676  7.3994
# 3  2021-01-18  5.5666  6.3042  7.5672

# %%
#Verificação de segurança(upload)

try:
  client.upload_file(Filename='cotacao_aws.csv', Bucket=BUCKET, Key='cotacao_aws.csv')
except Exception as e:
  print(str(e))
# Out:
# Failed to upload cotacao_aws.csv to ebac-modulo-39-sagemaker1/cotacao_aws.csv: An error occurred (AccessDenied) when calling the PutObject operation: Access Denied
